# %% [markdown]
# # Pandas
#
# Herramienta de manipulación de datos de alto nivel, construida sobre Numpy y permite el análisis y limpieza de datos en bruto.
#
# Los principales tipos de datos que pueden representarse con pandas son:
#
# * Datos tabulares que tienen columnas de tipo heterogéneo con etiquetas en columnas y filas.
# * Series temporales
#
# Permite leer y escribir datos en diferentes formatos como lo son: CSV, JSON, Excel, bases SQL

# %% [markdown]
# Se instala empleando
#
# * pip install pandas
# * conda install pandas

# %% [markdown]
# # Manipulación de datos con pandas

# %%
# Importar librerias
import pandas as pd # Importar pandas
import numpy  as np # Importar numpy

# %%
# Leer archivos separados por comas, extension .csv
df = pd.read_excel('../data/Datos_Rotacion.xlsx')
df.head(5) ## mostrar primeros 5 registros
# Out:
#   Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0       Si  41.0         Raramente       Ventas               1          2
# 1       No  49.0    Frecuentemente          IyD               8          1
# 2       Si   NaN         Raramente          IyD               2          2
# 3       No   NaN    Frecuentemente          IyD               3          4
# 4       No   NaN         Raramente          IyD               2          1
#
#   Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0        Ciencias                       2      F         Ejecutivo_Ventas
# 1        Ciencias                       3      M  Investigador_Cientifico
# 2            Otra                       4      M      Tecnico_Laboratorio
# 3        Ciencias                       4      F  Investigador_Cientifico
# 4           Salud                       1      M      Tecnico_Laboratorio
#
#    ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0  ...           Si                          11                    3
# 1  ...           No                          23                    4
# 2  ...           Si                          15                    3
# 3  ...           Si                          11                    3
# 4  ...           No                          12                    3
#
#    Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                 8              0                        1           6
# 1                10              3                        3          10
# 2                 7              3                        3           0
# 3                 8              3                        3           8
# 4                 6              3                        3           2
#
#    Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                 4                      0                           5
# 1                 7                      1                           7
# 2                 0                      0                           0
# 3                 7                      3                           0
# 4                 2                      2                           2
#
# [5 rows x 24 columns]

# %%
# dimensiones del dataframe
df.shape
# Out:
# (1470, 24)

# %%
df.query('Genero=="F"')
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si  41.0         Raramente       Ventas               1          2
# 3          No   NaN    Frecuentemente          IyD               3          4
# 6          No   NaN         Raramente          IyD               3          3
# 11         No   NaN         Raramente          IyD              15          2
# 15         No  29.0         Raramente          IyD              21          4
# ...       ...   ...               ...          ...             ...        ...
# 1457       No  40.0         Raramente          IyD               2          4
# 1458       No  35.0         Raramente          IyD               1          4
# 1460       No  29.0         Raramente          IyD              28          4
# 1462       No  39.0         Raramente       Ventas              24          1
# 1464       No  26.0         Raramente       Ventas               5          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0           Ciencias                       2      F         Ejecutivo_Ventas
# 3           Ciencias                       4      F  Investigador_Cientifico
# 6              Salud                       3      F      Tecnico_Laboratorio
# 11          Ciencias                       4      F      Tecnico_Laboratorio
# 15          Ciencias                       2      F     Director_Manofactura
# ...              ...                     ...    ...                      ...
# 1457           Salud                       3      F  Investigador_Cientifico
# 1458        Ciencias                       3      F  Investigador_Cientifico
# 1460           Salud                       4      F  Investigador_Cientifico
# 1462        Mercadeo                       2      F         Ejecutivo_Ventas
# 1464            Otra                       4      F     Representante_Ventas
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0     ...           Si                          11                    3
# 3     ...           Si                          11                    3
# 6     ...           Si                          20                    4
# 11    ...           Si                          12                    3
# 15    ...           No                          11                    3
# ...   ...          ...                         ...                  ...
# 1457  ...           No                          14                    3
# 1458  ...           No                          12                    3
# 1460  ...           No                          14                    3
# 1462  ...           No                          11                    3
# 1464  ...           No                          18                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                    8              0                        1           6
# 3                    8              3                        3           8
# 6                   12              3                        2           1
# 11                  10              3                        3           9
# 15                  10              1                        3          10
# ...                ...            ...                      ...         ...
# 1457                20              2                        3           5
# 1458                 4              5                        3           4
# 1460                 5              3                        1           5
# 1462                21              2                        2          20
# 1464                 5              2                        3           4
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                    4                      0                           5
# 3                    7                      3                           0
# 6                    0                      0                           0
# 11                   5                      0                           8
# 15                   9                      8                           8
# ...                ...                    ...                         ...
# 1457                 3                      0                           2
# 1458                 3                      1                           1
# 1460                 4                      0                           4
# 1462                 9                      9                           6
# 1464                 2                      0                           0
#
# [588 rows x 24 columns]

# %%
# Información general del data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 24 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rotación                     1470 non-null   object
#  1   Edad                         1458 non-null   float64
#  2   Viaje de Negocios            1470 non-null   object
#  3   Departamento                 1470 non-null   object
#  4   Distancia_Casa               1470 non-null   int64
#  5   Educación                    1470 non-null   int64
#  6   Campo_Educación              1470 non-null   object
#  7   Satisfacción_Ambiental       1470 non-null   int64
#  8   Genero                       1470 non-null   object
#  9   Cargo                        1470 non-null   object
#  10  Satisfación_Laboral          1470 non-null   int64
#  11  Estado_Civil                 1470 non-null   object
#  12  Ingreso_Mensual              1470 non-null   int64
#  13  Trabajos_Anteriores          1470 non-null   int64
#  14  Horas_Extra                  1470 non-null   object
#  15  Porcentaje_aumento_salarial  1470 non-null   int64
#  16  Rendimiento_Laboral          1470 non-null   int64
#  17  Años_Experiencia             1470 non-null   int64
#  18  Capacitaciones               1470 non-null   int64
#  19  Equilibrio_Trabajo_Vida      1470 non-null   int64
#  20  Antigüedad                   1470 non-null   int64
#  21  Antigüedad_Cargo             1470 non-null   int64
#  22  Años_ultima_promoción        1470 non-null   int64
#  23  Años_acargo_con_mismo_jefe   1470 non-null   int64
# dtypes: float64(1), int64(15), object(8)
# memory usage: 275.8+ KB

# %%
list(df.columns)
# Out:
# ['Rotación',
#  'Edad',
#  'Viaje de Negocios',
#  'Departamento',
#  'Distancia_Casa',
#  'Educación',
#  'Campo_Educación',
#  'Satisfacción_Ambiental',
#  'Genero',
#  'Cargo',
#  'Satisfación_Laboral',
#  'Estado_Civil',
#  'Ingreso_Mensual',
#  'Trabajos_Anteriores',
#  'Horas_Extra',
#  'Porcentaje_aumento_salarial',
#  'Rendimiento_Laboral',
#  'Años_Experiencia',
#  'Capacitaciones',
#  'Equilibrio_Trabajo_Vida',
#  'Antigüedad',
#  'Antigüedad_Cargo',
#  'Años_ultima_promoción',
#  'Años_acargo_con_mismo_jefe']

# %%
# Tipos de datos que existen en las columnas del dataframe
df.dtypes
# Out:
# Rotación                        object
# Edad                           float64
# Viaje de Negocios               object
# Departamento                    object
# Distancia_Casa                   int64
# Educación                        int64
# Campo_Educación                 object
# Satisfacción_Ambiental           int64
# Genero                          object
# Cargo                           object
# Satisfación_Laboral              int64
# Estado_Civil                    object
# Ingreso_Mensual                  int64
# Trabajos_Anteriores              int64
# Horas_Extra                     object
# Porcentaje_aumento_salarial      int64
# Rendimiento_Laboral              int64
# Años_Experiencia                 int64
# Capacitaciones                   int64
# Equilibrio_Trabajo_Vida          int64
# Antigüedad                       int64
# Antigüedad_Cargo                 int64
# Años_ultima_promoción            int64
# Años_acargo_con_mismo_jefe       int64
# dtype: object

# %% [markdown]
# El metodo .describe() de los dataframes muestra un resumen de la estadistica descriptiva general de las columnas numericas del dataframe.
#
# * Promedio (mean)
# * Desviacion estandard (std)
# * Valor minimo
# * Valor maximo
# * Cuartiles (25%, 50% y 75%)

# %%
df.describe() # No muestra la informacion de las columnas categoricas
# Out:
#               Edad  Distancia_Casa    Educación  Satisfacción_Ambiental  \
# count  1458.000000     1470.000000  1470.000000             1470.000000
# mean     36.938957        9.192517     2.912925                2.721769
# std       9.143467        8.106864     1.024165                1.093082
# min      18.000000        1.000000     1.000000                1.000000
# 25%      30.000000        2.000000     2.000000                2.000000
# 50%      36.000000        7.000000     3.000000                3.000000
# 75%      43.000000       14.000000     4.000000                4.000000
# max      60.000000       29.000000     5.000000                4.000000
#
#        Satisfación_Laboral  Ingreso_Mensual  Trabajos_Anteriores  \
# count          1470.000000      1470.000000          1470.000000
# mean              2.728571      6502.931293             2.693197
# std               1.102846      4707.956783             2.498009
# min               1.000000      1009.000000             0.000000
# 25%               2.000000      2911.000000             1.000000
# 50%               3.000000      4919.000000             2.000000
# 75%               4.000000      8379.000000             4.000000
# max               4.000000     19999.000000             9.000000
#
#        Porcentaje_aumento_salarial  Rendimiento_Laboral  Años_Experiencia  \
# count                  1470.000000          1470.000000       1470.000000
# mean                     15.209524             3.153741         11.279592
# std                       3.659938             0.360824          7.780782
# min                      11.000000             3.000000          0.000000
# 25%                      12.000000             3.000000          6.000000
# 50%                      14.000000             3.000000         10.000000
# 75%                      18.000000             3.000000         15.000000
# max                      25.000000             4.000000         40.000000
#
#        Capacitaciones  Equilibrio_Trabajo_Vida   Antigüedad  Antigüedad_Cargo  \
# count     1470.000000              1470.000000  1470.000000       1470.000000
# mean         2.799320                 2.761224     7.008163          4.229252
# std          1.289271                 0.706476     6.126525          3.623137
# min          0.000000                 1.000000     0.000000          0.000000
# 25%          2.000000                 2.000000     3.000000          2.000000
# 50%          3.000000                 3.000000     5.000000          3.000000
# 75%          3.000000                 3.000000     9.000000          7.000000
# max          6.000000                 4.000000    40.000000         18.000000
#
#        Años_ultima_promoción  Años_acargo_con_mismo_jefe
# count            1470.000000                 1470.000000
# mean                2.187755                    4.123129
# std                 3.222430                    3.568136
# min                 0.000000                    0.000000
# 25%                 0.000000                    2.000000
# 50%                 1.000000                    3.000000
# 75%                 3.000000                    7.000000
# max                15.000000                   17.000000

# %% [markdown]
# Seleccion e Indexación

# %%
df.describe(include=['O']) # Mostrar variables categoricas
# Out:
#        Rotación Viaje de Negocios Departamento Campo_Educación Genero  \
# count      1470              1470         1470            1470   1470
# unique        2                 3            3               6      2
# top          No         Raramente          IyD        Ciencias      M
# freq       1233              1043          961             606    882
#
#                    Cargo Estado_Civil Horas_Extra
# count               1470         1470        1470
# unique                 9            3           2
# top     Ejecutivo_Ventas       Casado          No
# freq                 326          673        1054

# %%
# Regresara todos los datos de la Estado_Civil
df['Estado_Civil']
# Out:
# 0       Soltero
# 1        Casado
# 2       Soltero
# 3        Casado
# 4        Casado
#          ...
# 1465     Casado
# 1466     Casado
# 1467     Casado
# 1468     Casado
# 1469     Casado
# Name: Estado_Civil, Length: 1470, dtype: object

# %%
df.Estado_Civil
# Out:
# 0       Soltero
# 1        Casado
# 2       Soltero
# 3        Casado
# 4        Casado
#          ...
# 1465     Casado
# 1466     Casado
# 1467     Casado
# 1468     Casado
# 1469     Casado
# Name: Estado_Civil, Length: 1470, dtype: object

# %%
# Seleccionar dos o mas columnas

df[['Estado_Civil','Rotación','Genero']]
# Out:
#      Estado_Civil Rotación Genero
# 0         Soltero       Si      F
# 1          Casado       No      M
# 2         Soltero       Si      M
# 3          Casado       No      F
# 4          Casado       No      M
# ...           ...      ...    ...
# 1465       Casado       No      M
# 1466       Casado       No      M
# 1467       Casado       No      M
# 1468       Casado       No      M
# 1469       Casado       No      M
#
# [1470 rows x 3 columns]

# %%
## Crear una nueva columna

df['Aumento_Salarial'] = df.Ingreso_Mensual * 0.20
df.head()
# Out:
#   Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0       Si  41.0         Raramente       Ventas               1          2
# 1       No  49.0    Frecuentemente          IyD               8          1
# 2       Si   NaN         Raramente          IyD               2          2
# 3       No   NaN    Frecuentemente          IyD               3          4
# 4       No   NaN         Raramente          IyD               2          1
#
#   Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0        Ciencias                       2      F         Ejecutivo_Ventas
# 1        Ciencias                       3      M  Investigador_Cientifico
# 2            Otra                       4      M      Tecnico_Laboratorio
# 3        Ciencias                       4      F  Investigador_Cientifico
# 4           Salud                       1      M      Tecnico_Laboratorio
#
#    ...  Porcentaje_aumento_salarial Rendimiento_Laboral  Años_Experiencia  \
# 0  ...                           11                   3                 8
# 1  ...                           23                   4                10
# 2  ...                           15                   3                 7
# 3  ...                           11                   3                 8
# 4  ...                           12                   3                 6
#
#    Capacitaciones Equilibrio_Trabajo_Vida  Antigüedad  Antigüedad_Cargo  \
# 0               0                       1           6                 4
# 1               3                       3          10                 7
# 2               3                       3           0                 0
# 3               3                       3           8                 7
# 4               3                       3           2                 2
#
#    Años_ultima_promoción  Años_acargo_con_mismo_jefe  Aumento_Salarial
# 0                      0                           5            1198.6
# 1                      1                           7            1026.0
# 2                      0                           0             418.0
# 3                      3                           0             581.8
# 4                      2                           2             693.6
#
# [5 rows x 25 columns]

# %%
df.drop('Aumento_Salarial',axis=1) # axis = 0 elimina filas(index) axis = 1 elimina columnas
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si  41.0         Raramente       Ventas               1          2
# 1          No  49.0    Frecuentemente          IyD               8          1
# 2          Si   NaN         Raramente          IyD               2          2
# 3          No   NaN    Frecuentemente          IyD               3          4
# 4          No   NaN         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No  36.0    Frecuentemente          IyD              23          2
# 1466       No  39.0         Raramente          IyD               6          1
# 1467       No  27.0         Raramente          IyD               4          3
# 1468       No  49.0    Frecuentemente       Ventas               2          3
# 1469       No  34.0         Raramente          IyD               8          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0           Ciencias                       2      F         Ejecutivo_Ventas
# 1           Ciencias                       3      M  Investigador_Cientifico
# 2               Otra                       4      M      Tecnico_Laboratorio
# 3           Ciencias                       4      F  Investigador_Cientifico
# 4              Salud                       1      M      Tecnico_Laboratorio
# ...              ...                     ...    ...                      ...
# 1465           Salud                       3      M      Tecnico_Laboratorio
# 1466           Salud                       4      M      Representante_Salud
# 1467        Ciencias                       2      M     Director_Manofactura
# 1468           Salud                       4      M         Ejecutivo_Ventas
# 1469           Salud                       2      M      Tecnico_Laboratorio
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0     ...           Si                          11                    3
# 1     ...           No                          23                    4
# 2     ...           Si                          15                    3
# 3     ...           Si                          11                    3
# 4     ...           No                          12                    3
# ...   ...          ...                         ...                  ...
# 1465  ...           No                          17                    3
# 1466  ...           No                          15                    3
# 1467  ...           Si                          20                    4
# 1468  ...           No                          14                    3
# 1469  ...           No                          12                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                    8              0                        1           6
# 1                   10              3                        3          10
# 2                    7              3                        3           0
# 3                    8              3                        3           8
# 4                    6              3                        3           2
# ...                ...            ...                      ...         ...
# 1465                17              3                        3           5
# 1466                 9              5                        3           7
# 1467                 6              0                        3           6
# 1468                17              3                        2           9
# 1469                 6              3                        4           4
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                    4                      0                           5
# 1                    7                      1                           7
# 2                    0                      0                           0
# 3                    7                      3                           0
# 4                    2                      2                           2
# ...                ...                    ...                         ...
# 1465                 2                      0                           3
# 1466                 7                      1                           7
# 1467                 2                      0                           3
# 1468                 6                      0                           8
# 1469                 3                      1                           2
#
# [1470 rows x 24 columns]

# %%
df.head()
# Out:
#   Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0       Si  41.0         Raramente       Ventas               1          2
# 1       No  49.0    Frecuentemente          IyD               8          1
# 2       Si   NaN         Raramente          IyD               2          2
# 3       No   NaN    Frecuentemente          IyD               3          4
# 4       No   NaN         Raramente          IyD               2          1
#
#   Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0        Ciencias                       2      F         Ejecutivo_Ventas
# 1        Ciencias                       3      M  Investigador_Cientifico
# 2            Otra                       4      M      Tecnico_Laboratorio
# 3        Ciencias                       4      F  Investigador_Cientifico
# 4           Salud                       1      M      Tecnico_Laboratorio
#
#    ...  Porcentaje_aumento_salarial Rendimiento_Laboral  Años_Experiencia  \
# 0  ...                           11                   3                 8
# 1  ...                           23                   4                10
# 2  ...                           15                   3                 7
# 3  ...                           11                   3                 8
# 4  ...                           12                   3                 6
#
#    Capacitaciones Equilibrio_Trabajo_Vida  Antigüedad  Antigüedad_Cargo  \
# 0               0                       1           6                 4
# 1               3                       3          10                 7
# 2               3                       3           0                 0
# 3               3                       3           8                 7
# 4               3                       3           2                 2
#
#    Años_ultima_promoción  Años_acargo_con_mismo_jefe  Aumento_Salarial
# 0                      0                           5            1198.6
# 1                      1                           7            1026.0
# 2                      0                           0             418.0
# 3                      3                           0             581.8
# 4                      2                           2             693.6
#
# [5 rows x 25 columns]

# %%
# Para que quede grabado

# df = df.drop('Aumento_Salarial',axis=1) # Forma 1
df.drop('Aumento_Salarial', axis=1, inplace=True) # Forma 2

# %%
df.head()
# Out:
#   Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0       Si  41.0         Raramente       Ventas               1          2
# 1       No  49.0    Frecuentemente          IyD               8          1
# 2       Si   NaN         Raramente          IyD               2          2
# 3       No   NaN    Frecuentemente          IyD               3          4
# 4       No   NaN         Raramente          IyD               2          1
#
#   Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0        Ciencias                       2      F         Ejecutivo_Ventas
# 1        Ciencias                       3      M  Investigador_Cientifico
# 2            Otra                       4      M      Tecnico_Laboratorio
# 3        Ciencias                       4      F  Investigador_Cientifico
# 4           Salud                       1      M      Tecnico_Laboratorio
#
#    ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0  ...           Si                          11                    3
# 1  ...           No                          23                    4
# 2  ...           Si                          15                    3
# 3  ...           Si                          11                    3
# 4  ...           No                          12                    3
#
#    Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                 8              0                        1           6
# 1                10              3                        3          10
# 2                 7              3                        3           0
# 3                 8              3                        3           8
# 4                 6              3                        3           2
#
#    Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                 4                      0                           5
# 1                 7                      1                           7
# 2                 0                      0                           0
# 3                 7                      3                           0
# 4                 2                      2                           2
#
# [5 rows x 24 columns]

# %%
df.columns # nombres de las columnas
# Out:
# Index(['Rotación', 'Edad', 'Viaje de Negocios', 'Departamento',
#        'Distancia_Casa', 'Educación', 'Campo_Educación',
#        'Satisfacción_Ambiental', 'Genero', 'Cargo', 'Satisfación_Laboral',
#        'Estado_Civil', 'Ingreso_Mensual', 'Trabajos_Anteriores', 'Horas_Extra',
#        'Porcentaje_aumento_salarial', 'Rendimiento_Laboral',
#        'Años_Experiencia', 'Capacitaciones', 'Equilibrio_Trabajo_Vida',
#        'Antigüedad', 'Antigüedad_Cargo', 'Años_ultima_promoción',
#        'Años_acargo_con_mismo_jefe'],
#       dtype='object')

# %%
df.index # nombres de los indices
# Out:
# RangeIndex(start=0, stop=1470, step=1)

# %% [markdown]
# Filtros

# %%
# seleccionar todas las filas donde el valor Income sea mayor que 0
df[df['Años_acargo_con_mismo_jefe']>5]
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 1          No  49.0    Frecuentemente          IyD               8          1
# 5          No   NaN    Frecuentemente          IyD               2          2
# 8          No   NaN    Frecuentemente          IyD              23          3
# 9          No   NaN         Raramente          IyD              27          3
# 11         No   NaN         Raramente          IyD              15          2
# ...       ...   ...               ...          ...             ...        ...
# 1451       No  38.0         Raramente       Ventas              10          2
# 1462       No  39.0         Raramente       Ventas              24          1
# 1463       No  31.0          No_Viaja          IyD               5          3
# 1466       No  39.0         Raramente          IyD               6          1
# 1468       No  49.0    Frecuentemente       Ventas               2          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 1           Ciencias                       3      M  Investigador_Cientifico
# 5           Ciencias                       4      M      Tecnico_Laboratorio
# 8           Ciencias                       4      M     Director_Manofactura
# 9              Salud                       3      M      Representante_Salud
# 11          Ciencias                       4      F      Tecnico_Laboratorio
# ...              ...                     ...    ...                      ...
# 1451        Ciencias                       1      F         Ejecutivo_Ventas
# 1462        Mercadeo                       2      F         Ejecutivo_Ventas
# 1463           Salud                       2      M     Director_Manofactura
# 1466           Salud                       4      M      Representante_Salud
# 1468           Salud                       4      M         Ejecutivo_Ventas
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 1     ...           No                          23                    4
# 5     ...           No                          13                    3
# 8     ...           No                          21                    4
# 9     ...           No                          13                    3
# 11    ...           Si                          12                    3
# ...   ...          ...                         ...                  ...
# 1451  ...           No                          11                    3
# 1462  ...           No                          11                    3
# 1463  ...           No                          19                    3
# 1466  ...           No                          15                    3
# 1468  ...           No                          14                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 1                   10              3                        3          10
# 5                    8              2                        2           7
# 8                   10              2                        3           9
# 9                   17              3                        2           7
# 11                  10              3                        3           9
# ...                ...            ...                      ...         ...
# 1451                10              1                        3          10
# 1462                21              2                        2          20
# 1463                10              2                        3           9
# 1466                 9              5                        3           7
# 1468                17              3                        2           9
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 1                    7                      1                           7
# 5                    7                      3                           6
# 8                    7                      1                           8
# 9                    7                      7                           7
# 11                   5                      0                           8
# ...                ...                    ...                         ...
# 1451                 7                      1                           9
# 1462                 9                      9                           6
# 1463                 4                      1                           7
# 1466                 7                      1                           7
# 1468                 6                      0                           8
#
# [516 rows x 24 columns]

# %%
## Forma 2
df.query('Años_acargo_con_mismo_jefe > 5')
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 1          No  49.0    Frecuentemente          IyD               8          1
# 5          No   NaN    Frecuentemente          IyD               2          2
# 8          No   NaN    Frecuentemente          IyD              23          3
# 9          No   NaN         Raramente          IyD              27          3
# 11         No   NaN         Raramente          IyD              15          2
# ...       ...   ...               ...          ...             ...        ...
# 1451       No  38.0         Raramente       Ventas              10          2
# 1462       No  39.0         Raramente       Ventas              24          1
# 1463       No  31.0          No_Viaja          IyD               5          3
# 1466       No  39.0         Raramente          IyD               6          1
# 1468       No  49.0    Frecuentemente       Ventas               2          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 1           Ciencias                       3      M  Investigador_Cientifico
# 5           Ciencias                       4      M      Tecnico_Laboratorio
# 8           Ciencias                       4      M     Director_Manofactura
# 9              Salud                       3      M      Representante_Salud
# 11          Ciencias                       4      F      Tecnico_Laboratorio
# ...              ...                     ...    ...                      ...
# 1451        Ciencias                       1      F         Ejecutivo_Ventas
# 1462        Mercadeo                       2      F         Ejecutivo_Ventas
# 1463           Salud                       2      M     Director_Manofactura
# 1466           Salud                       4      M      Representante_Salud
# 1468           Salud                       4      M         Ejecutivo_Ventas
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 1     ...           No                          23                    4
# 5     ...           No                          13                    3
# 8     ...           No                          21                    4
# 9     ...           No                          13                    3
# 11    ...           Si                          12                    3
# ...   ...          ...                         ...                  ...
# 1451  ...           No                          11                    3
# 1462  ...           No                          11                    3
# 1463  ...           No                          19                    3
# 1466  ...           No                          15                    3
# 1468  ...           No                          14                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 1                   10              3                        3          10
# 5                    8              2                        2           7
# 8                   10              2                        3           9
# 9                   17              3                        2           7
# 11                  10              3                        3           9
# ...                ...            ...                      ...         ...
# 1451                10              1                        3          10
# 1462                21              2                        2          20
# 1463                10              2                        3           9
# 1466                 9              5                        3           7
# 1468                17              3                        2           9
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 1                    7                      1                           7
# 5                    7                      3                           6
# 8                    7                      1                           8
# 9                    7                      7                           7
# 11                   5                      0                           8
# ...                ...                    ...                         ...
# 1451                 7                      1                           9
# 1462                 9                      9                           6
# 1463                 4                      1                           7
# 1466                 7                      1                           7
# 1468                 6                      0                           8
#
# [516 rows x 24 columns]

# %%
# Seleccionar las filas donde Años_acargo_con_mismo_jefe sea mayor que 5 y Estado Soltero
df[(df['Años_acargo_con_mismo_jefe']>5) & (df['Estado_Civil']=='Soltero')]
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 5          No   NaN    Frecuentemente          IyD               2          2
# 8          No   NaN    Frecuentemente          IyD              23          3
# 11         No   NaN         Raramente          IyD              15          2
# 22         No  34.0         Raramente          IyD               7          4
# 26         Si  32.0    Frecuentemente          IyD              16          1
# ...       ...   ...               ...          ...             ...        ...
# 1414       No  47.0         Raramente          IyD              25          3
# 1424       No  35.0         Raramente          IyD               9          4
# 1429       No  39.0         Raramente          IyD              24          1
# 1450       No  35.0         Raramente           RH              26          4
# 1463       No  31.0          No_Viaja          IyD               5          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 5           Ciencias                       4      M      Tecnico_Laboratorio
# 8           Ciencias                       4      M     Director_Manofactura
# 11          Ciencias                       4      F      Tecnico_Laboratorio
# 22          Ciencias                       1      F   Director_Investigación
# 26          Ciencias                       2      F  Investigador_Cientifico
# ...              ...                     ...    ...                      ...
# 1414           Salud                       1      M      Representante_Salud
# 1424           Salud                       2      M  Investigador_Cientifico
# 1429        Ciencias                       1      M  Investigador_Cientifico
# 1450        Ciencias                       3      F         Recursos_Humanos
# 1463           Salud                       2      M     Director_Manofactura
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 5     ...           No                          13                    3
# 8     ...           No                          21                    4
# 11    ...           Si                          12                    3
# 22    ...           No                          11                    3
# 26    ...           Si                          22                    4
# ...   ...          ...                         ...                  ...
# 1414  ...           No                          23                    4
# 1424  ...           No                          19                    3
# 1429  ...           No                          13                    3
# 1450  ...           Si                          16                    3
# 1463  ...           No                          19                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 5                    8              2                        2           7
# 8                   10              2                        3           9
# 11                  10              3                        3           9
# 22                  13              4                        3          12
# 26                  10              5                        3          10
# ...                ...            ...                      ...         ...
# 1414                25              3                        3          17
# 1424                10              5                        3          10
# 1429                18              2                        3           7
# 1450                 9              2                        3           9
# 1463                10              2                        3           9
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 5                    7                      3                           6
# 8                    7                      1                           8
# 11                   5                      0                           8
# 22                   6                      2                          11
# 26                   2                      6                           7
# ...                ...                    ...                         ...
# 1414                14                     12                          11
# 1424                 7                      0                           8
# 1429                 7                      1                           7
# 1450                 0                      1                           7
# 1463                 4                      1                           7
#
# [151 rows x 24 columns]

# %% [markdown]
# Datos Faltantes (Missing data)

# %%
# Verificar si hay datos faltantes por columna
df.isnull().any()
# Out:
# Rotación                       False
# Edad                            True
# Viaje de Negocios              False
# Departamento                   False
# Distancia_Casa                 False
# Educación                      False
# Campo_Educación                False
# Satisfacción_Ambiental         False
# Genero                         False
# Cargo                          False
# Satisfación_Laboral            False
# Estado_Civil                   False
# Ingreso_Mensual                False
# Trabajos_Anteriores            False
# Horas_Extra                    False
# Porcentaje_aumento_salarial    False
# Rendimiento_Laboral            False
# Años_Experiencia               False
# Capacitaciones                 False
# Equilibrio_Trabajo_Vida        False
# Antigüedad                     False
# Antigüedad_Cargo               False
# Años_ultima_promoción          False
# Años_acargo_con_mismo_jefe     False
# dtype: bool

# %%
# Numero de datos faltantes por columna
df.isnull().sum()
# Out:
# Rotación                        0
# Edad                           12
# Viaje de Negocios               0
# Departamento                    0
# Distancia_Casa                  0
# Educación                       0
# Campo_Educación                 0
# Satisfacción_Ambiental          0
# Genero                          0
# Cargo                           0
# Satisfación_Laboral             0
# Estado_Civil                    0
# Ingreso_Mensual                 0
# Trabajos_Anteriores             0
# Horas_Extra                     0
# Porcentaje_aumento_salarial     0
# Rendimiento_Laboral             0
# Años_Experiencia                0
# Capacitaciones                  0
# Equilibrio_Trabajo_Vida         0
# Antigüedad                      0
# Antigüedad_Cargo                0
# Años_ultima_promoción           0
# Años_acargo_con_mismo_jefe      0
# dtype: int64

# %%
df[df['Edad'].isnull()==True]
# Out:
#    Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 2        Si   NaN         Raramente          IyD               2          2
# 3        No   NaN    Frecuentemente          IyD               3          4
# 4        No   NaN         Raramente          IyD               2          1
# 5        No   NaN    Frecuentemente          IyD               2          2
# 6        No   NaN         Raramente          IyD               3          3
# 7        No   NaN         Raramente          IyD              24          1
# 8        No   NaN    Frecuentemente          IyD              23          3
# 9        No   NaN         Raramente          IyD              27          3
# 10       No   NaN         Raramente          IyD              16          3
# 11       No   NaN         Raramente          IyD              15          2
# 12       No   NaN         Raramente          IyD              26          1
# 13       No   NaN         Raramente          IyD              19          2
#
#    Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 2             Otra                       4      M      Tecnico_Laboratorio
# 3         Ciencias                       4      F  Investigador_Cientifico
# 4            Salud                       1      M      Tecnico_Laboratorio
# 5         Ciencias                       4      M      Tecnico_Laboratorio
# 6            Salud                       3      F      Tecnico_Laboratorio
# 7         Ciencias                       4      M      Tecnico_Laboratorio
# 8         Ciencias                       4      M     Director_Manofactura
# 9            Salud                       3      M      Representante_Salud
# 10           Salud                       1      M      Tecnico_Laboratorio
# 11        Ciencias                       4      F      Tecnico_Laboratorio
# 12        Ciencias                       1      M  Investigador_Cientifico
# 13           Salud                       2      M      Tecnico_Laboratorio
#
#     ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 2   ...           Si                          15                    3
# 3   ...           Si                          11                    3
# 4   ...           No                          12                    3
# 5   ...           No                          13                    3
# 6   ...           Si                          20                    4
# 7   ...           No                          22                    4
# 8   ...           No                          21                    4
# 9   ...           No                          13                    3
# 10  ...           No                          13                    3
# 11  ...           Si                          12                    3
# 12  ...           No                          17                    3
# 13  ...           No                          11                    3
#
#     Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 2                  7              3                        3           0
# 3                  8              3                        3           8
# 4                  6              3                        3           2
# 5                  8              2                        2           7
# 6                 12              3                        2           1
# 7                  1              2                        3           1
# 8                 10              2                        3           9
# 9                 17              3                        2           7
# 10                 6              5                        3           5
# 11                10              3                        3           9
# 12                 5              1                        2           5
# 13                 3              2                        3           2
#
#     Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 2                  0                      0                           0
# 3                  7                      3                           0
# 4                  2                      2                           2
# 5                  7                      3                           6
# 6                  0                      0                           0
# 7                  0                      0                           0
# 8                  7                      1                           8
# 9                  7                      7                           7
# 10                 4                      0                           3
# 11                 5                      0                           8
# 12                 2                      4                           3
# 13                 2                      1                           2
#
# [12 rows x 24 columns]

# %%
# Max cantidad de datos faltantes para un registro
max(df.isnull().sum(axis=1))
# Out:
# 1

# %%
# Eliminar todas las filas que tengan datos faltantes
df.dropna(axis=0) # cuando son filas no es neceario escribir axis=0
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si  41.0         Raramente       Ventas               1          2
# 1          No  49.0    Frecuentemente          IyD               8          1
# 14         Si  28.0         Raramente          IyD              24          3
# 15         No  29.0         Raramente          IyD              21          4
# 16         No  32.0         Raramente          IyD               5          2
# ...       ...   ...               ...          ...             ...        ...
# 1465       No  36.0    Frecuentemente          IyD              23          2
# 1466       No  39.0         Raramente          IyD               6          1
# 1467       No  27.0         Raramente          IyD               4          3
# 1468       No  49.0    Frecuentemente       Ventas               2          3
# 1469       No  34.0         Raramente          IyD               8          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0           Ciencias                       2      F         Ejecutivo_Ventas
# 1           Ciencias                       3      M  Investigador_Cientifico
# 14          Ciencias                       3      M      Tecnico_Laboratorio
# 15          Ciencias                       2      F     Director_Manofactura
# 16          Ciencias                       1      M  Investigador_Cientifico
# ...              ...                     ...    ...                      ...
# 1465           Salud                       3      M      Tecnico_Laboratorio
# 1466           Salud                       4      M      Representante_Salud
# 1467        Ciencias                       2      M     Director_Manofactura
# 1468           Salud                       4      M         Ejecutivo_Ventas
# 1469           Salud                       2      M      Tecnico_Laboratorio
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0     ...           Si                          11                    3
# 1     ...           No                          23                    4
# 14    ...           Si                          14                    3
# 15    ...           No                          11                    3
# 16    ...           Si                          12                    3
# ...   ...          ...                         ...                  ...
# 1465  ...           No                          17                    3
# 1466  ...           No                          15                    3
# 1467  ...           Si                          20                    4
# 1468  ...           No                          14                    3
# 1469  ...           No                          12                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                    8              0                        1           6
# 1                   10              3                        3          10
# 14                   6              4                        3           4
# 15                  10              1                        3          10
# 16                   7              5                        2           6
# ...                ...            ...                      ...         ...
# 1465                17              3                        3           5
# 1466                 9              5                        3           7
# 1467                 6              0                        3           6
# 1468                17              3                        2           9
# 1469                 6              3                        4           4
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                    4                      0                           5
# 1                    7                      1                           7
# 14                   2                      0                           3
# 15                   9                      8                           8
# 16                   2                      0                           5
# ...                ...                    ...                         ...
# 1465                 2                      0                           3
# 1466                 7                      1                           7
# 1467                 2                      0                           3
# 1468                 6                      0                           8
# 1469                 3                      1                           2
#
# [1458 rows x 24 columns]

# %%
# Eliminar todas las columnas que tengan datos faltantes
df.dropna(axis=1)
# Out:
#      Rotación Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si         Raramente       Ventas               1          2
# 1          No    Frecuentemente          IyD               8          1
# 2          Si         Raramente          IyD               2          2
# 3          No    Frecuentemente          IyD               3          4
# 4          No         Raramente          IyD               2          1
# ...       ...               ...          ...             ...        ...
# 1465       No    Frecuentemente          IyD              23          2
# 1466       No         Raramente          IyD               6          1
# 1467       No         Raramente          IyD               4          3
# 1468       No    Frecuentemente       Ventas               2          3
# 1469       No         Raramente          IyD               8          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0           Ciencias                       2      F         Ejecutivo_Ventas
# 1           Ciencias                       3      M  Investigador_Cientifico
# 2               Otra                       4      M      Tecnico_Laboratorio
# 3           Ciencias                       4      F  Investigador_Cientifico
# 4              Salud                       1      M      Tecnico_Laboratorio
# ...              ...                     ...    ...                      ...
# 1465           Salud                       3      M      Tecnico_Laboratorio
# 1466           Salud                       4      M      Representante_Salud
# 1467        Ciencias                       2      M     Director_Manofactura
# 1468           Salud                       4      M         Ejecutivo_Ventas
# 1469           Salud                       2      M      Tecnico_Laboratorio
#
#       Satisfación_Laboral  ... Horas_Extra  Porcentaje_aumento_salarial  \
# 0                       4  ...          Si                           11
# 1                       2  ...          No                           23
# 2                       3  ...          Si                           15
# 3                       3  ...          Si                           11
# 4                       2  ...          No                           12
# ...                   ...  ...         ...                          ...
# 1465                    4  ...          No                           17
# 1466                    1  ...          No                           15
# 1467                    2  ...          Si                           20
# 1468                    2  ...          No                           14
# 1469                    3  ...          No                           12
#
#       Rendimiento_Laboral Años_Experiencia  Capacitaciones  \
# 0                       3                8               0
# 1                       4               10               3
# 2                       3                7               3
# 3                       3                8               3
# 4                       3                6               3
# ...                   ...              ...             ...
# 1465                    3               17               3
# 1466                    3                9               5
# 1467                    4                6               0
# 1468                    3               17               3
# 1469                    3                6               3
#
#       Equilibrio_Trabajo_Vida  Antigüedad  Antigüedad_Cargo  \
# 0                           1           6                 4
# 1                           3          10                 7
# 2                           3           0                 0
# 3                           3           8                 7
# 4                           3           2                 2
# ...                       ...         ...               ...
# 1465                        3           5                 2
# 1466                        3           7                 7
# 1467                        3           6                 2
# 1468                        2           9                 6
# 1469                        4           4                 3
#
#       Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                         0                           5
# 1                         1                           7
# 2                         0                           0
# 3                         3                           0
# 4                         2                           2
# ...                     ...                         ...
# 1465                      0                           3
# 1466                      1                           7
# 1467                      0                           3
# 1468                      0                           8
# 1469                      1                           2
#
# [1470 rows x 23 columns]

# %% [markdown]
# Imputar datos faltantes

# %%
# Llenar los datos faltantes con el dato que nos interese
df.fillna(value=0)
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si  41.0         Raramente       Ventas               1          2
# 1          No  49.0    Frecuentemente          IyD               8          1
# 2          Si   0.0         Raramente          IyD               2          2
# 3          No   0.0    Frecuentemente          IyD               3          4
# 4          No   0.0         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No  36.0    Frecuentemente          IyD              23          2
# 1466       No  39.0         Raramente          IyD               6          1
# 1467       No  27.0         Raramente          IyD               4          3
# 1468       No  49.0    Frecuentemente       Ventas               2          3
# 1469       No  34.0         Raramente          IyD               8          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0           Ciencias                       2      F         Ejecutivo_Ventas
# 1           Ciencias                       3      M  Investigador_Cientifico
# 2               Otra                       4      M      Tecnico_Laboratorio
# 3           Ciencias                       4      F  Investigador_Cientifico
# 4              Salud                       1      M      Tecnico_Laboratorio
# ...              ...                     ...    ...                      ...
# 1465           Salud                       3      M      Tecnico_Laboratorio
# 1466           Salud                       4      M      Representante_Salud
# 1467        Ciencias                       2      M     Director_Manofactura
# 1468           Salud                       4      M         Ejecutivo_Ventas
# 1469           Salud                       2      M      Tecnico_Laboratorio
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0     ...           Si                          11                    3
# 1     ...           No                          23                    4
# 2     ...           Si                          15                    3
# 3     ...           Si                          11                    3
# 4     ...           No                          12                    3
# ...   ...          ...                         ...                  ...
# 1465  ...           No                          17                    3
# 1466  ...           No                          15                    3
# 1467  ...           Si                          20                    4
# 1468  ...           No                          14                    3
# 1469  ...           No                          12                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                    8              0                        1           6
# 1                   10              3                        3          10
# 2                    7              3                        3           0
# 3                    8              3                        3           8
# 4                    6              3                        3           2
# ...                ...            ...                      ...         ...
# 1465                17              3                        3           5
# 1466                 9              5                        3           7
# 1467                 6              0                        3           6
# 1468                17              3                        2           9
# 1469                 6              3                        4           4
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                    4                      0                           5
# 1                    7                      1                           7
# 2                    0                      0                           0
# 3                    7                      3                           0
# 4                    2                      2                           2
# ...                ...                    ...                         ...
# 1465                 2                      0                           3
# 1466                 7                      1                           7
# 1467                 2                      0                           3
# 1468                 6                      0                           8
# 1469                 3                      1                           2
#
# [1470 rows x 24 columns]

# %%
# Llenar los datos faltantes con el promedio de esa columna
df['Edad'].fillna(value=round(df['Edad'].mean(),0))
# Out:
# 0       41.0
# 1       49.0
# 2       37.0
# 3       37.0
# 4       37.0
#         ...
# 1465    36.0
# 1466    39.0
# 1467    27.0
# 1468    49.0
# 1469    34.0
# Name: Edad, Length: 1470, dtype: float64

# %%
## Datos unicos

df['Estado_Civil'].unique()
# Out:
# array(['Soltero', 'Casado', 'Divorciado'], dtype=object)

# %%
# Numero de valores unicos en el dataframe
df['Estado_Civil'].nunique()
# Out:
# 3

# %%
## Verificar Datos duplicados en todas las columnas
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Length: 1470, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.duplicated('Edad').sum()
# Out:
# 1426

# %%
## Eliminar Duplicados
df.drop_duplicates()
# Out:
#      Rotación  Edad Viaje de Negocios Departamento  Distancia_Casa  Educación  \
# 0          Si  41.0         Raramente       Ventas               1          2
# 1          No  49.0    Frecuentemente          IyD               8          1
# 2          Si   NaN         Raramente          IyD               2          2
# 3          No   NaN    Frecuentemente          IyD               3          4
# 4          No   NaN         Raramente          IyD               2          1
# ...       ...   ...               ...          ...             ...        ...
# 1465       No  36.0    Frecuentemente          IyD              23          2
# 1466       No  39.0         Raramente          IyD               6          1
# 1467       No  27.0         Raramente          IyD               4          3
# 1468       No  49.0    Frecuentemente       Ventas               2          3
# 1469       No  34.0         Raramente          IyD               8          3
#
#      Campo_Educación  Satisfacción_Ambiental Genero                    Cargo  \
# 0           Ciencias                       2      F         Ejecutivo_Ventas
# 1           Ciencias                       3      M  Investigador_Cientifico
# 2               Otra                       4      M      Tecnico_Laboratorio
# 3           Ciencias                       4      F  Investigador_Cientifico
# 4              Salud                       1      M      Tecnico_Laboratorio
# ...              ...                     ...    ...                      ...
# 1465           Salud                       3      M      Tecnico_Laboratorio
# 1466           Salud                       4      M      Representante_Salud
# 1467        Ciencias                       2      M     Director_Manofactura
# 1468           Salud                       4      M         Ejecutivo_Ventas
# 1469           Salud                       2      M      Tecnico_Laboratorio
#
#       ...  Horas_Extra Porcentaje_aumento_salarial  Rendimiento_Laboral  \
# 0     ...           Si                          11                    3
# 1     ...           No                          23                    4
# 2     ...           Si                          15                    3
# 3     ...           Si                          11                    3
# 4     ...           No                          12                    3
# ...   ...          ...                         ...                  ...
# 1465  ...           No                          17                    3
# 1466  ...           No                          15                    3
# 1467  ...           Si                          20                    4
# 1468  ...           No                          14                    3
# 1469  ...           No                          12                    3
#
#       Años_Experiencia Capacitaciones  Equilibrio_Trabajo_Vida  Antigüedad  \
# 0                    8              0                        1           6
# 1                   10              3                        3          10
# 2                    7              3                        3           0
# 3                    8              3                        3           8
# 4                    6              3                        3           2
# ...                ...            ...                      ...         ...
# 1465                17              3                        3           5
# 1466                 9              5                        3           7
# 1467                 6              0                        3           6
# 1468                17              3                        2           9
# 1469                 6              3                        4           4
#
#       Antigüedad_Cargo  Años_ultima_promoción  Años_acargo_con_mismo_jefe
# 0                    4                      0                           5
# 1                    7                      1                           7
# 2                    0                      0                           0
# 3                    7                      3                           0
# 4                    2                      2                           2
# ...                ...                    ...                         ...
# 1465                 2                      0                           3
# 1466                 7                      1                           7
# 1467                 2                      0                           3
# 1468                 6                      0                           8
# 1469                 3                      1                           2
#
# [1470 rows x 24 columns]

# %% [markdown]
# Estadistica Descriptiva

# %%
# Media Aritmetica
df.Ingreso_Mensual.mean()
# Out:
# 6502.931292517007

# %%
# Mediana
df.Ingreso_Mensual.median()
# Out:
# 4919.0

# %%
# Max
df.Ingreso_Mensual.max()
# Out:
# 19999

# %%
# Minimo
df.Ingreso_Mensual.min()
# Out:
# 1009

# %%
# Moda
df.Ingreso_Mensual.mode()
# Out:
# 0    2342
# Name: Ingreso_Mensual, dtype: int64

# %%
## Cantidad de datos por Viaje de Negocios

df['Viaje de Negocios'].value_counts()
# Out:
# Viaje de Negocios
# Raramente         1043
# Frecuentemente     277
# No_Viaja           150
# Name: count, dtype: int64

# %%
df[df['Ingreso_Mensual']>2500]['Viaje de Negocios'].value_counts()
# Out:
# Viaje de Negocios
# Raramente         885
# Frecuentemente    233
# No_Viaja          126
# Name: count, dtype: int64

# %%
## Cantidad de datos por Campo_Educación

df.Campo_Educación.value_counts()
# Out:
# Campo_Educación
# Ciencias       606
# Salud          464
# Mercadeo       159
# Tecnicos       132
# Otra            82
# Humanidades     27
# Name: count, dtype: int64

# %%
df.groupby('Campo_Educación')['Ingreso_Mensual'].sum().sort_values(ascending= False)
# Out:
# Campo_Educación
# Ciencias       3916753
# Salud          3020657
# Mercadeo       1168425
# Tecnicos        760096
# Otra            497867
# Humanidades     195511
# Name: Ingreso_Mensual, dtype: int64

# %% [markdown]
# Medidas de dispersión

# %%
# Varianza
df.Ingreso_Mensual.var()
# Out:
# 22164857.07151841

# %%
# Desviación tipica o desviación estandar
df.Ingreso_Mensual.std()
# Out:
# 4707.956783097994

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df['Ingreso_Mensual'].plot.hist(bins=60);

# %%
sns.countplot(x='Campo_Educación',data=df,order=df['Campo_Educación'].value_counts().index)
# Out:
# <Axes: xlabel='Campo_Educación', ylabel='count'>
